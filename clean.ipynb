# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp38-cp38-macosx_10_9_x86_64.whl.metadata (18 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl.metadata (5.6 kB)
# ...
# Using cached pandas-2.0.3-cp38-cp38-macosx_10_9_x86_64.whl (11.7 MB)
# Using cached numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('include/dataset/vehicle_information-columns.csv')
df2 = pd.read_csv('include/dataset/uk-traffic-accidents-columns.csv')

# %%
dfft = dfd[dfd[]]

# %%
df4 = dfd[['Accident_Index', 'Accident_Severity', 'Date', 'Day_of_Week',
           'Light_Conditions', 'Number_of_Casualties', 'Number_of_Vehicles',
           'Pedestrian_Crossing-Human_Control',
           'Pedestrian_Crossing-Physical_Facilities', 'Road_Surface_Conditions',
           'Speed_limit', 'Time', 'Weather_Conditions', 'Year_y']]

# %%
df4 = df4.head(2000)

# %%
df6 =df6.head(2000)

# %%
df6= dfd[['Accident_Index', 'Age_Band_of_Driver', 'Age_of_Vehicle',
       'Driver_Home_Area_Type', 'make', 'Sex_of_Driver',
       'Skidding_and_Overturning', 'X1st_Point_of_Impact', 'Year_x']]

# %%
df.columns
# Out:
# Index(['Accident_Index', 'Age_Band_of_Driver', 'Age_of_Vehicle',
#        'Driver_Home_Area_Type', 'make', 'Sex_of_Driver',
#        'Skidding_and_Overturning', 'X1st_Point_of_Impact', 'Year'],
#       dtype='object')

# %%
dfd.columns
# Out:
# Index(['Accident_Index', 'Age_Band_of_Driver', 'Age_of_Vehicle',
#        'Driver_Home_Area_Type', 'make', 'Sex_of_Driver',
#        'Skidding_and_Overturning', 'X1st_Point_of_Impact', 'Year_x',
#        'Accident_Severity', 'Date', 'Day_of_Week', 'Light_Conditions',
#        'Number_of_Casualties', 'Number_of_Vehicles',
#        'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Road_Surface_Conditions',
#        'Speed_limit', 'Time', 'Weather_Conditions', 'Year_y'],
#       dtype='object')

# %%
dfd = pd.merge(df, df2, on='Accident_Index', how='right')
dfd
# Out:
#         Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0        200501BS00001                NaN             NaN
# 1        200501BS00002            36 - 45             3.0
# 2        200501BS00003            26 - 35             5.0
# 3        200501BS00004            46 - 55             4.0
# 4        200501BS00005            46 - 55            10.0
# ...                ...                ...             ...
# 1174659  201091NM01935            46 - 55             NaN
# 1174660  201091NM01935            46 - 55             NaN
# 1174661  201091NM01964            36 - 45            11.0
# 1174662  201091NM01964            46 - 55             NaN
# 1174663  201091NM02142            26 - 35            13.0
#
#                 Driver_Home_Area_Type      make Sex_of_Driver  \
# 0                                 NaN       NaN           NaN
# 1        Data missing or out of range    DENNIS          Male
# 2                          Urban area    DENNIS          Male
# ...

# %%
df2 = pd.read_csv('include/dataset/vehicle_info.csv')
result = df2[df2['Skidding_and_Overturning'].notnull()]
result = result.head(1000)

# %%
select
    a.Number_of_Vehicles AS vehicle_number,
    v.make
    v.Age_of_Vehicle
# Out:
#         Accident_Index Accident_Severity Date Day_of_Week Light_Conditions  \
# 0        200501BS00001               NaN  NaN         NaN              NaN
# 1        200501BS00002               NaN  NaN         NaN              NaN
# 2        200501BS00003               NaN  NaN         NaN              NaN
# 3        200501BS00004               NaN  NaN         NaN              NaN
# 4        200501BS00005               NaN  NaN         NaN              NaN
# ...                ...               ...  ...         ...              ...
# 1048570  201091NM01760               NaN  NaN         NaN              NaN
# 1048571  201091NM01881               NaN  NaN         NaN              NaN
# 1048572  201091NM01935               NaN  NaN         NaN              NaN
# 1048573  201091NM01964               NaN  NaN         NaN              NaN
# 1048574  201091NM02142               NaN  NaN         NaN              NaN
#
#          Number_of_Casualties  Number_of_Vehicles  \
# ...

# %%
df_2 = df_2.head(1000)

# %%
df_2
# Out:
#      Accident_Index  Age_Band_of_Driver  Age_of_Vehicle  \
# 0              True                True            True
# 1              True                True           False
# 2              True                True            True
# 3              True                True           False
# 4              True                True            True
# ..              ...                 ...             ...
# 995            True                True            True
# 996            True                True            True
# 997            True                True            True
# 998            True                True           False
# 999            True                True            True
#
#      Driver_Home_Area_Type  make  Sex_of_Driver  Skidding_and_Overturning  \
# 0                     True  True           True                     False
# 1                     True  True           True                     False
# ...

# %%
df6.to_csv('include/dataset/vehicle_data.csv')

# %%
df4.to_csv('include/dataset/traffic_data.csv')

# %%
df6
# Out:
#      Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0     200501BS00001                NaN             NaN
# 1     200501BS00002            36 - 45             3.0
# 2     200501BS00003            26 - 35             5.0
# 3     200501BS00004            46 - 55             4.0
# 4     200501BS00005            46 - 55            10.0
# ...             ...                ...             ...
# 1995  200501CW11047            36 - 45             NaN
# 1996  200501CW11048                NaN             NaN
# 1997  200501CW11049            26 - 35             NaN
# 1998  200501CW11050                NaN             NaN
# 1999  200501CW11051                NaN             NaN
#
#              Driver_Home_Area_Type              make Sex_of_Driver  \
# 0                              NaN               NaN           NaN
# 1     Data missing or out of range            DENNIS          Male
# 2                       Urban area            DENNIS          Male
# ...

# %%
result
# Out:
#       Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 6      200401BS00009            26 - 35             NaN
# 73     200401BS00150            16 - 20             3.0
# 101    200401BS00197            36 - 45             3.0
# 138    200401BS00274            36 - 45             NaN
# 191    200401BS00352            26 - 35             3.0
# ...              ...                ...             ...
# 18564  200404C081704            16 - 20             7.0
# 18567  200404C082104            36 - 45             6.0
# 18568  200404C082204            16 - 20             3.0
# 18578  200404C083504            26 - 35            12.0
# 18579  200404C083604            36 - 45            25.0
#
#               Driver_Home_Area_Type        make Sex_of_Driver  \
# 6                        Urban area     PIAGGIO          Male
# 73                       Urban area      DUCATI          Male
# 101                      Urban area    KAWASAKI          Male
# ...

# %%
d4 = left_join_df[left_join_df['Sex_of_Driver'].notnull()]
d4 = left_join_df[left_join_df['Sex_of_Driver'].notnull()]

# %%
d4
# Out:
# Empty DataFrame
# Columns: [Accident_Index, Accident_Severity, Date, Day_of_Week, Light_Conditions, Number_of_Casualties, Number_of_Vehicles, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Road_Surface_Conditions, Speed_limit, Time, Weather_Conditions, Year_x, Age_Band_of_Driver, Age_of_Vehicle, Driver_Home_Area_Type, make, Sex_of_Driver, Skidding_and_Overturning, X1st_Point_of_Impact, Year_y]
# Index: []
#
# [0 rows x 22 columns]

# %%
left_join_df = pd.merge(df1, result, on='Accident_Index', how='right')
left_join_df
# Out:
#     Accident_Index Accident_Severity Date Day_of_Week Light_Conditions  \
# 0    200401BS00009               NaN  NaN         NaN              NaN
# 1    200401BS00150               NaN  NaN         NaN              NaN
# 2    200401BS00197               NaN  NaN         NaN              NaN
# 3    200401BS00274               NaN  NaN         NaN              NaN
# 4    200401BS00352               NaN  NaN         NaN              NaN
# ..             ...               ...  ...         ...              ...
# 995  200404C081704               NaN  NaN         NaN              NaN
# 996  200404C082104               NaN  NaN         NaN              NaN
# 997  200404C082204               NaN  NaN         NaN              NaN
# 998  200404C083504               NaN  NaN         NaN              NaN
# 999  200404C083604               NaN  NaN         NaN              NaN
#
#      Number_of_Casualties  Number_of_Vehicles  \
# 0                     NaN                 NaN
# ...

# %%
df
# Out:
#         Accident_Index Accident_Severity        Date Day_of_Week  \
# 0        200501BS00001           Serious  04/01/2005     Tuesday
# 1        200501BS00002            Slight  05/01/2005   Wednesday
# 2        200501BS00003            Slight  06/01/2005    Thursday
# 3        200501BS00004            Slight  07/01/2005      Friday
# 4        200501BS00005            Slight  10/01/2005      Monday
# ...                ...               ...         ...         ...
# 1048570  201091NM01760            Slight  18/02/2010    Thursday
# 1048571  201091NM01881            Slight  21/02/2010      Sunday
# 1048572  201091NM01935            Slight  23/02/2010     Tuesday
# 1048573  201091NM01964           Serious  23/02/2010     Tuesday
# 1048574  201091NM02142           Serious  28/02/2010      Sunday
#
#                     Light_Conditions  Number_of_Casualties  \
# 0                           Daylight                     1
# 1              Darkness - lights lit                     1
# ...

# %%
df1 = df.head(10000)

# %%
df
# Out:
#         Accident_Index Accident_Severity        Date Day_of_Week  \
# 0        200501BS00001           Serious  04/01/2005     Tuesday
# 1        200501BS00002            Slight  05/01/2005   Wednesday
# 2        200501BS00003            Slight  06/01/2005    Thursday
# 3        200501BS00004            Slight  07/01/2005      Friday
# 4        200501BS00005            Slight  10/01/2005      Monday
# ...                ...               ...         ...         ...
# 1048570  201091NM01760            Slight  18/02/2010    Thursday
# 1048571  201091NM01881            Slight  21/02/2010      Sunday
# 1048572  201091NM01935            Slight  23/02/2010     Tuesday
# 1048573  201091NM01964           Serious  23/02/2010     Tuesday
# 1048574  201091NM02142           Serious  28/02/2010      Sunday
#
#                     Light_Conditions  Number_of_Casualties  \
# 0                           Daylight                     1
# 1              Darkness - lights lit                     1
# ...

# %%
df1.to_csv('include/dataset/traffics.csv')

# %%
dff = df1.notnull()
dff
# Out:
#       Accident_Index  Accident_Severity  Date  Day_of_Week  Light_Conditions  \
# 0               True               True  True         True              True
# 1               True               True  True         True              True
# 2               True               True  True         True              True
# 3               True               True  True         True              True
# 4               True               True  True         True              True
# ...              ...                ...   ...          ...               ...
# 9995            True               True  True         True              True
# 9996            True               True  True         True              True
# 9997            True               True  True         True              True
# 9998            True               True  True         True              True
# 9999            True               True  True         True              True
#
# ...

# %%
['Accident_Index', 'Accident_Severity', 'Date', 'Day_of_Week',
       'Light_Conditions', 'Number_of_Casualties', 'Number_of_Vehicles',
       'Pedestrian_Crossing-Human_Control',
       'Pedestrian_Crossing-Physical_Facilities', 'Road_Surface_Conditions',
       'Speed_limit', 'Time', 'Weather_Conditions', 'Year']

# %%
select 
    Accident_Index
    Age_Band_of_Driver
    Age_of_Vehicle
    Driver_Home_Area_Type
    Sex_of_Driver

# %%
result.columns
# Out:
# Index(['Accident_Index', 'Age_Band_of_Driver', 'Age_of_Vehicle',
#        'Driver_Home_Area_Type', 'make', 'Sex_of_Driver',
#        'Skidding_and_Overturning', 'X1st_Point_of_Impact', 'Year'],
#       dtype='object')

# %%
- Accident_Index
- Age_Band_of_Driver
- Age_of_Vehicle
- Driver_Home_Area_Type	
- make	
- Sex_of_Driver	
- Skidding_and_Overturning
- X1st_Point_of_Impact
- Year

Accident_Index:	string
Age_Band_of_Driver:	string	
Age_of_Vehicle:	float64	
Driver_Home_Area_Type:	string	
make:	string	
Sex_of_Driver:	string	
Skidding_and_Overturning:	string
X1st_Point_of_Impact:	string	
Year:	intiger64
